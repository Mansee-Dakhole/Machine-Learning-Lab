# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB

# %%
#step 1 : create the datset 
data = {
    'cheap' : ['yes','yes','no','yes','no'],
    'promo' : ['yes','no','yes','yes','no'],
    'buy' : ['yes','yes','no','yes','no']
}

# %%
df= pd.DataFrame(data)

# %%
#step 2 : Encode categorical variables
le_cheap = LabelEncoder()
le_promo = LabelEncoder()
le_buy = LabelEncoder()

# %%
df['cheap'] = le_cheap.fit_transform(df['cheap'])
df['promo'] = le_promo.fit_transform(df['promo'])
df['buy'] = le_buy.fit_transform(df['buy'])

# %%
#step 3 : features (X) and target (y)
X = df[['cheap','promo']]
y = df['buy']

# %%
#step 4 train naive bayes 
model = CategoricalNB()
model.fit(X,y)
# Out:
# CategoricalNB()

# %%
#step 5: predict on the same  data
prediction = model.predict(X)

# %%
#step 6 : show result with decoded labels 
df['Predicted_Buy'] =le_buy.inverse_transform(prediction)
df['Actual_buy'] = le_buy.inverse_transform(y)
print(df)
# Out:
#    cheap  promo  buy  Predicted_Buy  Actual_buy
# 0      1      1    1              1           1
# 1      1      0    1              1           1
# 2      0      1    0              0           0
# 3      1      1    1              1           1
# 4      0      0    0              0           0

# %%
print(df['promo'])
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: promo, dtype: int64

# %%
print(data['promo'])
# Out:
# ['yes', 'no', 'yes', 'yes', 'no']

# %%
# Out:
# CategoricalNB()

# %%
# Out:
#    weather  wind  play Predicted_Buy Actual_buy Predicted_play Actual_play
# 0        2     1     1           yes        yes            yes         yes
# 1        2     0     0            no         no             no          no
# 2        0     1     1           yes        yes            yes         yes
# 3        1     1     1           yes        yes            yes         yes
# 4        1     0     0            no         no             no          no
